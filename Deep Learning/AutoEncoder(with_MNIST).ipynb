# %% [markdown]
# <a href="https://colab.research.google.com/github/0001010/Learn-Growth/blob/main/AutoEncoder(with_MNIST).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MNIST데이터로 AutoEncoder구현하기
# - 이미지 데이터이므로 CNN을 사용할 예정이다.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

data = tf.keras.datasets.mnist

(x_train, y_train), (x_val, y_val) = data.load_data()

print(x_train.shape, y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28) (60000,)

# %%
x_train = x_train.reshape(-1, 28, 28, 1)

x_train = x_train / 255.

# %%
encoder_input = tf.keras.layers.Input(shape = (28, 28, 1))

# 28 X 28
model1 = tf.keras.layers.Conv2D(32, 3, padding = 'same')(encoder_input)
model1 = tf.keras.layers.BatchNormalization()(model1)
model1 = tf.keras.layers.LeakyReLU()(model1)

# 28 X 28 -> 14 X 14
model1 = tf.keras.layers.Conv2D(64, 3, strides = 2, padding = 'same')(model1)
model1 = tf.keras.layers.BatchNormalization()(model1)
model1 = tf.keras.layers.LeakyReLU()(model1)

# 14 X 14 -> 7 X 7
model1 = tf.keras.layers.Conv2D(64, 3, strides = 2, padding = 'same')(model1)
model1 = tf.keras.layers.BatchNormalization()(model1)
model1 = tf.keras.layers.LeakyReLU()(model1)

# 7 X 7
model1 = tf.keras.layers.Conv2D(64, 3, padding = 'same')(model1)
model1 = tf.keras.layers.BatchNormalization()(model1)
model1 = tf.keras.layers.LeakyReLU()(model1)

model1 = tf.keras.layers.Flatten()(model1)

# 2D 좌표로 표기하기 위해 2를 출력값으로 지정
encoder_output = tf.keras.layers.Dense(2)(model1)

encoder = tf.keras.models.Model(encoder_input, encoder_output)
encoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 28, 28, 32)        128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 6274
# =================================================================
# Total params: 99,842
# Trainable params: 99,394
# Non-trainable params: 448
# _________________________________________________________________

# %%
decoder_input = tf.keras.Input(shape = (2,))

model2 = tf.keras.layers.Dense(7*7*64)(decoder_input)
model2 = tf.keras.layers.Reshape((7, 7, 64))(model2)

# 7 X 7 -> 7 X 7
model2 = tf.keras.layers.Conv2DTranspose(64, 3, strides = 1, padding = 'same')(model2)
model2 = tf.keras.layers.BatchNormalization()(model2)
model2 = tf.keras.layers.LeakyReLU()(model2)

# 7 X 7 -> 14 X 14
model2 = tf.keras.layers.Conv2DTranspose(64, 3, strides = 2, padding = 'same')(model2)
model2 = tf.keras.layers.BatchNormalization()(model2)
model2 = tf.keras.layers.LeakyReLU()(model2)

# 14 X 14 -> 28 X 28

model2 = tf.keras.layers.Conv2DTranspose(64, 3, strides = 2, padding = 'same')(model2)
model2 = tf.keras.layers.BatchNormalization()(model2)
model2 = tf.keras.layers.LeakyReLU()(model2)

# 28 X 28 -> 28 X 28

model2 = tf.keras.layers.Conv2DTranspose(32, 3, strides = 1, padding = 'same')(model2)
model2 = tf.keras.layers.BatchNormalization()(model2)
model2 = tf.keras.layers.LeakyReLU()(model2)

decoder_output = tf.keras.layers.Conv2DTranspose(1, 3, strides = 1, padding = 'same', activation = 'sigmoid')(model2)

decoder = tf.keras.models.Model(decoder_input, decoder_output)

decoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 2)]               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 14, 14, 64)        36928
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 64)        36928
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 28, 28, 32)        18464
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 28, 28, 1)         289
# =================================================================
# Total params: 139,841
# Trainable params: 139,393
# Non-trainable params: 448
# _________________________________________________________________

# %%
encoder_in = tf.keras.layers.Input(shape = (28, 28, 1))
con = encoder(encoder_in)
decoder_out = decoder(con)

auto_encoder = tf.keras.models.Model(encoder_in, decoder_out)

# %%
auto_encoder.compile(optimizer = tf.keras.optimizers.Adam(0.0005),
              loss = tf.keras.losses.MeanSquaredError())

auto_encoder.fit(x_train, x_train,
          batch_size = 32,
          epochs = 100)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 65s 18ms/step - loss: 0.0513
# Epoch 2/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0448
# Epoch 3/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0431
# Epoch 4/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0420
# Epoch 5/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0414
# Epoch 6/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0408
# Epoch 7/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0405
# Epoch 8/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0401
# Epoch 9/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0399
# Epoch 10/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0396
# Epoch 11/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0394
# Epoch 12/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0392
# Epoch 13/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0391
# Epoch 14/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0389
# Epoch 15/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0388
# Epoch 16/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0387
# Epoch 17/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0385
# Epoch 18/100
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0384
# Epoch 19/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0383
# Epoch 20/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0382
# Epoch 21/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0381
# Epoch 22/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0380
# Epoch 23/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0380
# Epoch 24/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0379
# Epoch 25/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0378
# Epoch 26/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0378
# Epoch 27/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0377
# Epoch 28/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0376
# Epoch 29/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0375
# Epoch 30/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0375
# Epoch 31/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0374
# Epoch 32/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0374
# Epoch 33/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0373
# Epoch 34/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0373
# Epoch 35/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0372
# Epoch 36/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0372
# Epoch 37/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0371
# Epoch 38/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0371
# Epoch 39/100
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0371
# Epoch 40/100
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0370
# Epoch 41/100
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0370
# Epoch 42/100
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0369
# Epoch 43/100
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0369
# Epoch 44/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0369
# Epoch 45/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0368
# Epoch 46/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0368
# Epoch 47/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0367
# Epoch 48/100
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0367
# Epoch 49/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0367
# Epoch 50/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0366
# Epoch 51/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0366
# Epoch 52/100
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0366
# Epoch 53/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0366
# Epoch 54/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0365
# Epoch 55/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0365
# Epoch 56/100
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0364
# Epoch 57/100
# 1875/1875 [==============================] - 35s 19ms/step - loss: 0.0364
# Epoch 58/100
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0364
# Epoch 59/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0364
# Epoch 60/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0363
# Epoch 61/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0363
# Epoch 62/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0363
# Epoch 63/100
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0362
# Epoch 64/100
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0362
# Epoch 65/100
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0362
# Epoch 66/100
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0362
# Epoch 67/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0361
# Epoch 68/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0361
# Epoch 69/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0361
# Epoch 70/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0361
# Epoch 71/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0361
# Epoch 72/100
# 1875/1875 [==============================] - 35s 18ms/step - loss: 0.0361
# Epoch 73/100
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.0360
# Epoch 74/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0360
# Epoch 75/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0360
# Epoch 76/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0360
# Epoch 77/100
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0359
# Epoch 78/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0359
# Epoch 79/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0359
# Epoch 80/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0359
# Epoch 81/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0358
# Epoch 82/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0358
# Epoch 83/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0358
# Epoch 84/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0358
# Epoch 85/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0358
# Epoch 86/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0357
# Epoch 87/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0357
# Epoch 88/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0357
# Epoch 89/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0357
# Epoch 90/100
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0357
# Epoch 91/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0356
# Epoch 92/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0356
# Epoch 93/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0356
# Epoch 94/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0356
# Epoch 95/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0356
# Epoch 96/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0356
# Epoch 97/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0356
# Epoch 98/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0355
# Epoch 99/100
# 1875/1875 [==============================] - 33s 17ms/step - loss: 0.0355
# Epoch 100/100
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0355

# %%
xy = encoder.predict(x_train)
xy.shape
# Out:
# (60000, 2)

# %%
encoder.save('model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
f, ax = plt.subplots(figsize = (15, 12))

plt.scatter(x = xy[:, 0], y = xy[:, 1],
            c = y_train,
            cmap = plt.get_cmap('Paired'), s = 3)
plt.colorbar()

plt.show()

# %% [markdown]
# - 생각보다 Label간의 구분이 잘된다.
# - 조금 걸리는 부분은 4와 9의 범위가 겹쳐져있어서 decoding하는 과정에서 4와 9를 구분하기 어려울것 같다.

# %%
decoded_images = auto_encoder.predict(x_train)

# %%
# Original Images

f, ax = plt.subplots(3,5)
f.set_size_inches(12, 6)

for i in range(15):
  ax[i//5, i%5].imshow(x_train[i].reshape(28, 28), cmap = 'gray')
  ax[i//5, i%5].axis('off')

plt.tight_layout()
plt.title('Original Images')


# Decoder Images

f, ax = plt.subplots(3,5)
f.set_size_inches(12, 6)

for i in range(15):
  ax[i//5, i%5].imshow(decoded_images[i].reshape(28, 28), cmap = 'gray')
  ax[i//5, i%5].axis('off')

plt.tight_layout()
plt.title('Auto_encoder Images')
plt.show()

# %% [markdown]
# ## 노이즈 넣어서 Denoising해보기
# - MNIST데이터로 진행
# - 위에서 사용한 autoencoder모델을 사용할 예정

# %%
x_val = x_val.reshape(-1, 28, 28, 1)

x_val = x_val / 255.

noise = 0.5

x_train_noisy = x_train + noise * np.random.normal(loc = 0.0, scale = 1.0, size = x_train.shape)
x_val_noisy = x_val + noise + np.random.normal(loc = 0.0, scale = 1.0, size = x_val.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.) # np.clip는 max값을 넘어가는 친구들의 값을 max로 맞춰줌
x_val_noisy = np.clip(x_val_noisy, 0., 1.)

# %%
ax1 = plt.subplot(1,2,1) 
plt.imshow(x_val[0].reshape(28, 28), cmap = 'gray')

ax2 = plt.subplot(1,2,2)
plt.imshow(x_val_noisy[0].reshape(28, 28), cmap = 'gray')

plt.show()

# %% [markdown]
# - 원본데이터에 노이즈를 집어넣어보겠다. imshow로 출력해보았을때 원본의 데이터를 찾아보기 어려울 정도다.

# %%
# 위에서 사용된 autoencoder모델을 사용해서 학습해보자
auto_encoder.compile(optimizer = tf.keras.optimizers.Adam(0.0005),
              loss = tf.keras.losses.MeanSquaredError()) 

auto_encoder.fit(x_train_noisy, x_train,
          batch_size = 64,
          epochs = 100,
          shuffle = True,
          validation_data = (x_val_noisy, x_val))
# Out:
# Epoch 1/100
# 938/938 [==============================] - 62s 32ms/step - loss: 0.0547 - val_loss: 0.0885
# Epoch 2/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0485 - val_loss: 0.0715
# Epoch 3/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0471 - val_loss: 0.0673
# Epoch 4/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0462 - val_loss: 0.0675
# Epoch 5/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0456 - val_loss: 0.0697
# Epoch 6/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0452 - val_loss: 0.0674
# Epoch 7/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0447 - val_loss: 0.0706
# Epoch 8/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0444 - val_loss: 0.0689
# Epoch 9/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0441 - val_loss: 0.0698
# Epoch 10/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0438 - val_loss: 0.0684
# Epoch 11/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0436 - val_loss: 0.0751
# Epoch 12/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0434 - val_loss: 0.0716
# Epoch 13/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0432 - val_loss: 0.0753
# Epoch 14/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0429 - val_loss: 0.0699
# Epoch 15/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0428 - val_loss: 0.0713
# Epoch 16/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0426 - val_loss: 0.0719
# Epoch 17/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0425 - val_loss: 0.0722
# Epoch 18/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0423 - val_loss: 0.0709
# Epoch 19/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0422 - val_loss: 0.0749
# Epoch 20/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0421 - val_loss: 0.0732
# Epoch 21/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0420 - val_loss: 0.0734
# Epoch 22/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0419 - val_loss: 0.0731
# Epoch 23/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0417 - val_loss: 0.0721
# Epoch 24/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0416 - val_loss: 0.0742
# Epoch 25/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0416 - val_loss: 0.0725
# Epoch 26/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0415 - val_loss: 0.0728
# Epoch 27/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0414 - val_loss: 0.0766
# Epoch 28/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0413 - val_loss: 0.0761
# Epoch 29/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0412 - val_loss: 0.0743
# Epoch 30/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0412 - val_loss: 0.0759
# Epoch 31/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0410 - val_loss: 0.0719
# Epoch 32/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0410 - val_loss: 0.0739
# Epoch 33/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0409 - val_loss: 0.0743
# Epoch 34/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0408 - val_loss: 0.0744
# Epoch 35/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0408 - val_loss: 0.0748
# Epoch 36/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0407 - val_loss: 0.0739
# Epoch 37/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0406 - val_loss: 0.0731
# Epoch 38/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0406 - val_loss: 0.0745
# Epoch 39/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0405 - val_loss: 0.0751
# Epoch 40/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0404 - val_loss: 0.0746
# Epoch 41/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0404 - val_loss: 0.0739
# Epoch 42/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0403 - val_loss: 0.0759
# Epoch 43/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0402 - val_loss: 0.0748
# Epoch 44/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0402 - val_loss: 0.0752
# Epoch 45/100
# 938/938 [==============================] - 28s 30ms/step - loss: 0.0402 - val_loss: 0.0751
# Epoch 46/100
# 938/938 [==============================] - 28s 30ms/step - loss: 0.0401 - val_loss: 0.0739
# Epoch 47/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0400 - val_loss: 0.0740
# Epoch 48/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0400 - val_loss: 0.0747
# Epoch 49/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0399 - val_loss: 0.0756
# Epoch 50/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0399 - val_loss: 0.0762
# Epoch 51/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0398 - val_loss: 0.0739
# Epoch 52/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0398 - val_loss: 0.0733
# Epoch 53/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0397 - val_loss: 0.0763
# Epoch 54/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0397 - val_loss: 0.0739
# Epoch 55/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0396 - val_loss: 0.0749
# Epoch 56/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0396 - val_loss: 0.0738
# Epoch 57/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0396 - val_loss: 0.0746
# Epoch 58/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0395 - val_loss: 0.0750
# Epoch 59/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0395 - val_loss: 0.0753
# Epoch 60/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0394 - val_loss: 0.0743
# Epoch 61/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0394 - val_loss: 0.0750
# Epoch 62/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0393 - val_loss: 0.0757
# Epoch 63/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0393 - val_loss: 0.0747
# Epoch 64/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0393 - val_loss: 0.0764
# Epoch 65/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0392 - val_loss: 0.0766
# Epoch 66/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0392 - val_loss: 0.0751
# Epoch 67/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0391 - val_loss: 0.0760
# Epoch 68/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0391 - val_loss: 0.0745
# Epoch 69/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0391 - val_loss: 0.0751
# Epoch 70/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0390 - val_loss: 0.0757
# Epoch 71/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0390 - val_loss: 0.0751
# Epoch 72/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0390 - val_loss: 0.0762
# Epoch 73/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0389 - val_loss: 0.0751
# Epoch 74/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0389 - val_loss: 0.0746
# Epoch 75/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0389 - val_loss: 0.0764
# Epoch 76/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0389 - val_loss: 0.0753
# Epoch 77/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0388 - val_loss: 0.0751
# Epoch 78/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0388 - val_loss: 0.0755
# Epoch 79/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0387 - val_loss: 0.0751
# Epoch 80/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0387 - val_loss: 0.0756
# Epoch 81/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0387 - val_loss: 0.0750
# Epoch 82/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0386 - val_loss: 0.0766
# Epoch 83/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0386 - val_loss: 0.0765
# Epoch 84/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0386 - val_loss: 0.0756
# Epoch 85/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0386 - val_loss: 0.0753
# Epoch 86/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0385 - val_loss: 0.0767
# Epoch 87/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0385 - val_loss: 0.0757
# Epoch 88/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0385 - val_loss: 0.0762
# Epoch 89/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0384 - val_loss: 0.0776
# Epoch 90/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0384 - val_loss: 0.0759
# Epoch 91/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0384 - val_loss: 0.0764
# Epoch 92/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0384 - val_loss: 0.0751
# Epoch 93/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0383 - val_loss: 0.0772
# Epoch 94/100
# 938/938 [==============================] - 29s 31ms/step - loss: 0.0383 - val_loss: 0.0784
# Epoch 95/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0383 - val_loss: 0.0772
# Epoch 96/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0382 - val_loss: 0.0762
# Epoch 97/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0383 - val_loss: 0.0765
# Epoch 98/100
# 938/938 [==============================] - 28s 30ms/step - loss: 0.0382 - val_loss: 0.0760
# Epoch 99/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0382 - val_loss: 0.0778
# Epoch 100/100
# 938/938 [==============================] - 29s 30ms/step - loss: 0.0382 - val_loss: 0.0763

# %%
decoded_imgs = auto_encoder.predict(x_val)

n = 10
plt.figure(figsize=(20, 6))

for i in range(1, n):
    ax = plt.subplot(3, n, i)
    plt.imshow(x_val[i].reshape(28, 28))
    plt.gray()

    ax = plt.subplot(3, n, i + n)
    plt.imshow(x_val_noisy[i].reshape(28, 28))
    plt.gray()

    ax = plt.subplot(3, n, i + 2*n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
plt.show()

# %% [markdown]
# - 제일 첫번째 줄이 원본데이터이고 두번째줄이 노이즈가 삽입된 데이터 마지막 줄이 denoising 된 데이터이다.
#
# - 결과적으로 몇개를 제외하면 denosing이 잘되었다.
